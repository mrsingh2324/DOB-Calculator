# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsingh2324/DOB-Calculator/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

a=[2,5,7,9,3,11,14,16,10,13,18]
b=[21,19,24,17,22,25,24,27,21,25,27]

plt.scatter(a, b)
plt.show()
